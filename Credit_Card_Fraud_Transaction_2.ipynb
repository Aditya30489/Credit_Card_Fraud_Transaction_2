# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/creditcard_2023.csv")
data
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 0       0.519014 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794
# 1       0.406466 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469
# 2       0.743511 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045
# 3       0.518269 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048
# 4       0.658849 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666
# ...          ...       ...       ...  ...       ...       ...       ...
# 568625 -0.370393  0.189694 -0.938153  ...  0.167503  0.419731  1.288249
# 568626 -0.016935 -0.147733  0.483894  ...  0.031874  0.388161 -0.154257
# 568627 -0.070958 -0.019997 -0.122048  ...  0.140788  0.536523 -0.211100
# 568628  0.580568 -0.207723  0.893527  ... -0.060381 -0.195609 -0.175488
# 568629 -0.347613 -0.340814  0.253971  ...  0.534853 -0.291514  0.157303
#
#              V24       V25       V26       V27       V28    Amount  Class
# 0       0.165959  0.126280 -0.434824 -0.081230 -0.151045  17982.10      0
# 1      -0.577395  0.190090  0.296503 -0.248052 -0.064512   6531.37      0
# 2      -1.154666 -0.605564 -0.312895 -0.300258 -0.244718   2513.54      0
# 3      -1.893131  1.003963 -0.515950 -0.165316  0.048424   5384.44      0
# 4       0.312561 -0.414116  1.071126  0.023712  0.419117  14278.97      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 568625 -0.900861  0.560661 -0.006018  3.308968  0.081564   4394.16      1
# 568626 -0.846452 -0.153443  1.961398 -1.528642  1.704306   4653.40      1
# 568627 -0.448909  0.540073 -0.755836 -0.487540 -0.268741  23572.85      1
# 568628 -0.554643 -0.099669 -1.434931 -0.159269 -0.076251  10160.83      1
# 568629  0.931030 -0.349423 -1.090974 -1.575113  0.722936  21493.92      1
#
# [568630 rows x 31 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data.describe().T
# Out:
#            count          mean            std        min            25%  \
# id      568630.0  2.843145e+05  164149.486122   0.000000  142157.250000
# V1      568630.0 -5.638058e-17       1.000001  -3.495584      -0.565286
# V2      568630.0 -1.319545e-16       1.000001 -49.966572      -0.486678
# V3      568630.0 -3.518788e-17       1.000001  -3.183760      -0.649299
# V4      568630.0 -2.879008e-17       1.000001  -4.951222      -0.656020
# V5      568630.0  7.997245e-18       1.000001  -9.952786      -0.293496
# V6      568630.0 -3.958636e-17       1.000001 -21.111108      -0.445871
# V7      568630.0 -3.198898e-17       1.000001  -4.351839      -0.283533
# V8      568630.0  2.109273e-17       1.000001 -10.756342      -0.192257
# V9      568630.0  3.998623e-17       1.000001  -3.751919      -0.568745
# V10     568630.0  1.991314e-16       1.000001  -3.163276      -0.590101
#  20  V20     568630 non-null  float64
#  21  V21     568630 non-null  float64
#  22  V22     568630 non-null  float64
#  23  V23     568630 non-null  float64
#  24  V24     568630 non-null  float64
#  25  V25     568630 non-null  float64
#  26  V26     568630 non-null  float64
#  27  V27     568630 non-null  float64
#  28  V28     568630 non-null  float64
#  29  Amount  568630 non-null  float64
#  30  Class   568630 non-null  int64
# dtypes: float64(29), int64(2)
# memory usage: 134.5 MB

# %%
data.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.shape
# Out:
# (568630, 31)

# %% [markdown]
# Checking for any duplicate data

# %%
features = [col for col in data.columns if col not in ['id', 'Class']]

# %%
dup_rows=data[data.duplicated()]
print("Duplicated rows")
print(dup_rows)
# Out:
# Duplicated rows
# Empty DataFrame
# Columns: [id, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# OBSERVATIONS:
#
# 1) NO NULL VALUES 2) NO DUPLICATE VALUES 3) NO CATEGORICAL DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(12,10))
data.hist(ax=fig)
plt.tight_layout()
# Out:
# <ipython-input-18-b078852f680d>:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.hist(ax=fig)

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Splitting dataset into train and test sets

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

x=data.drop(['Class','id'],axis=1).values
y=data['Class'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=69, stratify=data['Class'],shuffle=True)

# %%
scaler = StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
######   FUNCTIONS
def model_results(model):
  pred=model.predict(x_test)
  pred=np.where(pred>0.5,1,0)
  print(classification_report(y_test,pred))
  cm=confusion_matrix(y_test,pred)
  display=ConfusionMatrixDisplay(confusion_matrix=cm)
  display.plot()
  plt.show()

def model_history(history):
  training_loss = history.history['loss']
  validation_loss = history.history['val_loss']
  plt.plot(training_loss, label='Training Loss')
  plt.plot(validation_loss, label='Validation Loss')
  plt.title('Training and Validation Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()

# %%
import tensorflow as tf
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        min_delta=1e-2,
        patience=2,
        verbose=1,
    )
]

# %% [markdown]
# BASIC NEURAL NETWORK

# %%
def create_simple_nnmodel(neurons):
    model = Sequential()
    model.add(Dense(neurons, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
start_time = time.time()
nn_model = create_simple_nnmodel(len(features))
history = nn_model.fit(x_train, y_train, epochs=10, batch_size=512, verbose=1, validation_split=0.2, callbacks=callbacks)
print(f'training time: {round(time.time()-start_time, 2)} seconds')
model_history(history)
# Out:
# Epoch 1/10
# 622/622 [==============================] - 4s 5ms/step - loss: 0.1540 - accuracy: 0.9431 - val_loss: 0.0934 - val_accuracy: 0.9645
# Epoch 2/10
# 622/622 [==============================] - 2s 2ms/step - loss: 0.0809 - accuracy: 0.9687 - val_loss: 0.0689 - val_accuracy: 0.9738
# Epoch 3/10
# 622/622 [==============================] - 1s 2ms/step - loss: 0.0615 - accuracy: 0.9760 - val_loss: 0.0537 - val_accuracy: 0.9794
# Epoch 4/10
# 622/622 [==============================] - 1s 2ms/step - loss: 0.0485 - accuracy: 0.9812 - val_loss: 0.0428 - val_accuracy: 0.9846
# Epoch 5/10
# 622/622 [==============================] - 2s 3ms/step - loss: 0.0390 - accuracy: 0.9860 - val_loss: 0.0346 - val_accuracy: 0.9884
# Epoch 6/10
# 622/622 [==============================] - 1s 2ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 0.0279 - val_accuracy: 0.9919
# Epoch 7/10
# 622/622 [==============================] - 2s 3ms/step - loss: 0.0261 - accuracy: 0.9925 - val_loss: 0.0233 - val_accuracy: 0.9935
# Epoch 8/10
# 622/622 [==============================] - 2s 4ms/step - loss: 0.0217 - accuracy: 0.9945 - val_loss: 0.0196 - val_accuracy: 0.9951
# Epoch 8: early stopping
# training time: 16.28 seconds

# %%
nn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 29)                870
#
#  dense_7 (Dense)             (None, 1)                 30
#
# =================================================================
# Total params: 900 (3.52 KB)
# Trainable params: 900 (3.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_results(nn_model)
# Out:
# 5331/5331 [==============================] - 9s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     85295
#            1       0.99      0.99      0.99     85294
#
#     accuracy                           0.99    170589
#    macro avg       0.99      0.99      0.99    170589
# weighted avg       0.99      0.99      0.99    170589

# %% [markdown]
# CNN MODEL

# %%
import time

def create_cnnmodel(input_length):
    # Define model architecture
    model = keras.Sequential([
        Conv1D(filters=5, kernel_size=10, activation="relu", input_shape=(input_length, 1), strides=2),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(32, activation="relu"),
        Dense(1, activation="sigmoid")
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

start_time = time.time()
cnn_model = create_cnnmodel(len(features))
history = cnn_model.fit(x_train, y_train, epochs=20, batch_size=512, verbose=1, validation_split=0.2, callbacks=callbacks)
print(f'training time: {round(time.time()-start_time, 2)} seconds')
model_history(history)
# Out:
# Epoch 1/20
# 622/622 [==============================] - 5s 7ms/step - loss: 0.1772 - accuracy: 0.9383 - val_loss: 0.1016 - val_accuracy: 0.9607
# Epoch 2/20
# 622/622 [==============================] - 3s 5ms/step - loss: 0.0875 - accuracy: 0.9654 - val_loss: 0.0742 - val_accuracy: 0.9700
# Epoch 3/20
# 622/622 [==============================] - 3s 4ms/step - loss: 0.0708 - accuracy: 0.9723 - val_loss: 0.0646 - val_accuracy: 0.9746
# Epoch 4/20
# 622/622 [==============================] - 3s 4ms/step - loss: 0.0627 - accuracy: 0.9756 - val_loss: 0.0592 - val_accuracy: 0.9765
# Epoch 5/20
# 622/622 [==============================] - 4s 6ms/step - loss: 0.0552 - accuracy: 0.9788 - val_loss: 0.0502 - val_accuracy: 0.9806
# Epoch 6/20
# 622/622 [==============================] - 4s 6ms/step - loss: 0.0487 - accuracy: 0.9815 - val_loss: 0.0447 - val_accuracy: 0.9834
# Epoch 7/20
# 622/622 [==============================] - 3s 5ms/step - loss: 0.0437 - accuracy: 0.9836 - val_loss: 0.0412 - val_accuracy: 0.9859
# Epoch 8/20
# 622/622 [==============================] - 3s 6ms/step - loss: 0.0398 - accuracy: 0.9855 - val_loss: 0.0378 - val_accuracy: 0.9870
# Epoch 8: early stopping
# training time: 64.19 seconds

# %%
model_results(cnn_model)
# Out:
# 5331/5331 [==============================] - 14s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     85295
#            1       0.99      0.99      0.99     85294
#
#     accuracy                           0.99    170589
#    macro avg       0.99      0.99      0.99    170589
# weighted avg       0.99      0.99      0.99    170589

# %%
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 10, 5)             55
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 5)              0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 25)                0
#
#  dense_2 (Dense)             (None, 32)                832
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 920 (3.59 KB)
# Trainable params: 920 (3.59 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
